# %% [markdown]
# Name: Hans Angelo C. Guevarra <br>
# Course and Section: CPE 019 - CPE32S3 <br>
# Date of Submission: 2/7/24 <br>
# Instructor: Engr. Roman Richard <br>

# %%
# Code cell 1

import pandas as pd

brainFile = '/content/brainsize.csv'
brainFrame = pd.read_csv(brainFile, delim_whitespace=True, header=None)

# %%
# Code cell 2

brainFrame.head()
# Out:
#                                              0
# 0  Gender,FSIQ,VIQ,PIQ,Weight,Height,MRI_Count
# 1           Female,133,132,124,118,64.5,816932
# 2            Male,140,150,124,NaN,72.5,1001121
# 3            Male,139,123,150,143,73.3,1038437
# 4             Male,133,129,128,172,68.8,965353

# %%
# Code cell 3

brainFrame.describe()
# Out:
#                                                   0
# count                                            41
# unique                                           41
# top     Gender,FSIQ,VIQ,PIQ,Weight,Height,MRI_Count
# freq                                              1

# %%
# Code cell 4

import numpy as np
import matplotlib.pyplot as plt

# %%
# Code cell 5

menDf = brainFrame[(brainFrame.Gender == 'Male')]
womenDf = brainFrame[(brainFrame.Gender == 'Female')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-d6957048c8bd> in <cell line: 3>()
#       1 # Code cell 5
#       2
# ----> 3 menDf = brainFrame[(brainFrame.Gender == 'Male')]
#       4 womenDf = brainFrame[(brainFrame.Gender == 'Female')]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Gender'

# %%
# Code cell 6

menMeanSmarts = menDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(menMeanSmarts, menDf["MRI_Count"])
plt.show()
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-cb3b602e1d80> in <cell line: 3>()
#       1 # Code cell 6
#       2
# ----> 3 menMeanSmarts = menDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
#       4 plt.scatter(menMeanSmarts, menDf["MRI_Count"])
#       5 plt.show()
#
# NameError: name 'menDf' is not defined

# %%
# Code cell 7

womenMeanSmarts = womenDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(womenMeanSmarts, womenDf["MRI_Count"])
plt.show()
# %matplotlib inline

# %%
# Code cell 8

brainFrame.corr(methods='pearson')

# %%
# Code cell 9
womenDf.corr(methods='pearson')

# %%
# Code cell 10

menDf.corr(methods='pearson')

# %%
# Code cell 11

# !pip install seaborn

# %%
# Code cell 12

import seaborn as sns

wcorr = womenDf.corr()
sns.heatmap(wcorr)
#plt.savefig('attribute_correlations.png', tight_Layout=True)

# %%
# Code cell 13

mcorr = menDf.corr()
sns.heatmap(mcorr)
#plt.savefig('attribute_correlations.png', tight_Layout=True)

# %% [markdown]
# Many variable pairs present correlation close to zero. What does that mean? <br>
#
# <br>
#
# Why seperate the genders? <br>
# We separate the genders to see the difference between men and women.
# <br>
#
# What variables have stronger correlation with brain size (MRI_Count)? Is that expected? Explain. <br>

# %%
# Supplementary

Apple = '/content/apple_quality.csv'
af =  pd.read_csv(Apple)

# %%
af.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
af.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
gdf = af[(af.Quality ==  'Good')]
bdf = af[(af.Quality == 'bad' )]

# %%
GoodQ = gdf[["Sweetness", "Crunchiness", "Juiciness"]].mean(axis=1)
plt.scatter(GoodQ, gdf["Size"])
plt.show()
# %matplotlib inline

# %%
BadQ = bdf[["Sweetness", "Crunchiness", "Juiciness"]].mean(axis=1)
plt.scatter(BadQ, bdf["Size"])
plt.show()
# %matplotlib inline

# %%
af.corr(method='pearson')
# Out:
# <ipython-input-103-877e2ce81834>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   af.corr(method='pearson')
#                  A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# A_id         1.000000 -0.028911 -0.005730  -0.002378    -0.013111   0.006179
# Size        -0.028911  1.000000 -0.170702  -0.324680     0.169868  -0.018892
# Weight      -0.005730 -0.170702  1.000000  -0.154246    -0.095882  -0.092263
# Sweetness   -0.002378 -0.324680 -0.154246   1.000000    -0.037552   0.095882
# Crunchiness -0.013111  0.169868 -0.095882  -0.037552     1.000000  -0.259607
# Juiciness    0.006179 -0.018892 -0.092263   0.095882    -0.259607   1.000000
# Ripeness     0.000742 -0.134773 -0.243824  -0.273800    -0.201982  -0.097144
#
#              Ripeness
# A_id         0.000742
# Size        -0.134773
# ...

# %%
gdf.corr(method='pearson')
# Out:
# <ipython-input-108-216ebcf23c0a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   gdf.corr(method='pearson')
#              A_id  Size  Weight  Sweetness  Crunchiness  Juiciness  Ripeness
# A_id          NaN   NaN     NaN        NaN          NaN        NaN       NaN
# Size          NaN   NaN     NaN        NaN          NaN        NaN       NaN
# Weight        NaN   NaN     NaN        NaN          NaN        NaN       NaN
# Sweetness     NaN   NaN     NaN        NaN          NaN        NaN       NaN
# Crunchiness   NaN   NaN     NaN        NaN          NaN        NaN       NaN
# Juiciness     NaN   NaN     NaN        NaN          NaN        NaN       NaN
# Ripeness      NaN   NaN     NaN        NaN          NaN        NaN       NaN

# %%
bdf.corr(method='pearson')
# Out:
# <ipython-input-109-76b3b8b44dd6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bdf.corr(method='pearson')
#                  A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# A_id         1.000000 -0.006385 -0.025512  -0.017872     0.021580  -0.001342
# Size        -0.006385  1.000000 -0.007087  -0.346907     0.206501  -0.162808
# Weight      -0.025512 -0.007087  1.000000  -0.072695     0.028091   0.031632
# Sweetness   -0.017872 -0.346907 -0.072695   1.000000     0.169701  -0.067993
# Crunchiness  0.021580  0.206501  0.028091   0.169701     1.000000  -0.466129
# Juiciness   -0.001342 -0.162808  0.031632  -0.067993    -0.466129   1.000000
# Ripeness     0.026245 -0.324418 -0.232406  -0.486456    -0.319040   0.173087
#
#              Ripeness
# A_id         0.026245
# Size        -0.324418
# ...

# %%
# !pip install seaborn

# %%
import seaborn as sns

gcorr = gdf.corr()
sns.heatmap(gcorr)
plt.savefig('attribute_correlations.png')
# Out:
# <ipython-input-112-2270a8233440>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   gcorr = gdf.corr()

# %%
bcorr = bdf.corr()
sns.heatmap(bcorr)
plt.savefig('attribute_correlations.png')
# Out:
# <ipython-input-113-d83ab1cd003a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bcorr = bdf.corr()
